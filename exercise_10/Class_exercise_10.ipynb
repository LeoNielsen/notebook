# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import auc, roc_curve, confusion_matrix

# %%
data = pd.read_csv("./AB_NYC_2019.csv")

# %%
data["is_cheap"] = data["price"].median() > data["price"]

data
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
x_data = data[["longitude","latitude"]].to_numpy()
y_data = data[["is_cheap"]].to_numpy()

X_train, X_test, y_train, y_test = train_test_split(
             x_data, y_data, test_size = 0.2, random_state=42)

k = 2

neigh = KNeighborsClassifier(n_neighbors=k)
neigh.fit(X_train, y_train)

y_pred = neigh.predict(X_test)
print(neigh.score(X_test, y_test))
# Out:
# C:\Users\leoni\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\neighbors\_classification.py:207: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# 0.6326822783515696

# %%
fpr, tpr, _ = roc_curve(y_test, y_pred, pos_label=True)
auc(fpr,tpr)
# Out:
# 0.6343822916371226

# %%
df = pd.get_dummies(data[['neighbourhood','neighbourhood_group','room_type']])

X_train, X_test, y_train, y_test = train_test_split(
             df, y_data, test_size = 0.2, random_state=42)

X_train = df[['latitude', 'longitude','number_of_reviews','reviews_per_month']].to_numpy()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [114], line 6
#       1 df = pd.get_dummies(data[['neighbourhood','neighbourhood_group','room_type']])
#       3 X_train, X_test, y_train, y_test = train_test_split(
#       4              df, y_data, test_size = 0.2, random_state=42)
# ----> 6 X_train = df[['latitude', 'longitude','number_of_reviews','reviews_per_month']].to_numpy()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:3811, in DataFrame.__getitem__(self, key)
#    3809     if is_iterator(key):
#    3810         key = list(key)
# -> 3811     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3813 # take() does not accept boolean indexers
#    3814 if getattr(indexer, "dtype", None) == bool:
#
# ...
